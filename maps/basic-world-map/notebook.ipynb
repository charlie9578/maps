# %% [markdown]
# # basic-world-map
#
# Run from the **repository root** (`jupyter lab` with cwd at repo root).
#
# **Kernel:** **Maps (.venv)**. Install map deps first: `pip install -r maps/basic-world-map/requirements.txt`

# %%
import importlib.util

from lib.paths import map_dir, repo_root

MAP_SLUG = "basic-world-map"
MAP_DIR = map_dir(MAP_SLUG)
OUTPUT_DIR = MAP_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print("Repo:", repo_root())
print("Map:", MAP_DIR)

main_path = MAP_DIR / "main.py"
module_name = MAP_SLUG.replace("-", "_") + "_main"
spec = importlib.util.spec_from_file_location(module_name, main_path)
main_mod = importlib.util.module_from_spec(spec)
assert spec.loader is not None
spec.loader.exec_module(main_mod)

main_mod.main()
# Out:
# Repo: D:\GitHub\maps
# Map: D:\GitHub\maps\maps\basic-world-map
# Wrote D:\GitHub\maps\maps\basic-world-map\output\world_map.png
