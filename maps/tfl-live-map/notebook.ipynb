# %% [markdown]
# # tfl-live-map
#
# Run from the **repository root** (`jupyter lab` with cwd at repo root).
#
# **Kernel:** **Maps (.venv)**. Install map deps first:
#
# ```bash
# .venv\Scripts\python.exe -m pip install -r maps/tfl-live-map/requirements.txt
# ```
#
# **Notebooks are JSON files** — edit them in Jupyter or VS Code; do not create `.ipynb` as plain text.
#
# This map is a **Dash dashboard**. Start it from a terminal (recommended):
#
# ```bash
# python maps/tfl-live-map/main.py
# ```
#
# Running `main()` in-notebook blocks the kernel.

# %%
from lib.paths import map_dir, repo_root

MAP_SLUG = "tfl-live-map"
MAP_DIR = map_dir(MAP_SLUG)

print("Repo:", repo_root())
print("Map:", MAP_DIR)
